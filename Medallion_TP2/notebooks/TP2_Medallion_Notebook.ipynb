# %% [markdown]
# # TP2 - Pipeline Medallion
# Notebook de réalisation avec Pandas et DuckDB.

# %% [markdown]
# ## Étape 0 - Installation
# Exécuter dans le terminal : `pip install -r requirements.txt` puis `docker compose up -d`.

# %%
# !python scripts/00_create_buckets.py

# %% [markdown]
# ## Variante 1 - Pipeline Pandas

# %%
# !python scripts/01_pandas_pipeline.py

# %% [markdown]
# ## Variante 2 - Pipeline DuckDB

# %%
# !python scripts/02_duckdb_pipeline.py

# %% [markdown]
# ## Visualisation Gold

# %%
# !python scripts/03_visualisation.py
